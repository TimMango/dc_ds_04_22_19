# %%
import pandas as pd

# %%
df = pd.read_csv('zillow_data.csv')

# %%
df.head()
# Out:
#    RegionID  RegionName      City State              Metro CountyName  \
# 0     84654       60657   Chicago    IL            Chicago       Cook
# 1     90668       75070  McKinney    TX  Dallas-Fort Worth     Collin
# 2     91982       77494      Katy    TX            Houston     Harris
# 3     84616       60614   Chicago    IL            Chicago       Cook
# 4     93144       79936   El Paso    TX            El Paso    El Paso
#
#    SizeRank   1996-04   1996-05   1996-06   ...     2017-07  2017-08  2017-09  \
# 0         1  334200.0  335400.0  336500.0   ...     1005500  1007500  1007800
# 1         2  235700.0  236900.0  236700.0   ...      308000   310000   312500
# 2         3  210400.0  212200.0  212200.0   ...      321000   320600   320200
# 3         4  498100.0  500900.0  503100.0   ...     1289800  1287700  1287400
# 4         5   77300.0   77300.0   77300.0   ...      119100   119400   120000
#
#    2017-10  2017-11  2017-12  2018-01  2018-02  2018-03  2018-04
# ...

# %%
for i in range(0, len(df)):
    print(i), print(df.iloc[i,0:3]), print(sum(df.iloc[i,7:])/len(df.iloc[i,7:]))
    print(sum(df.iloc[i,7:])/len(df.iloc[i,7:]))
# Out:
# 0
# RegionID        84654
# RegionName      60657
# City          Chicago
# Name: 0, dtype: object
# 743978.8679245283
# 1
# RegionID         90668
# RegionName       75070
# City          McKinney
# Name: 1, dtype: object
# 219655.84905660377
# 2
# RegionID      91982
# RegionName    77494
# City           Katy
# Name: 2, dtype: object
# 262110.56603773584
# 3
# RegionID        84616
# RegionName      60614
# City          Chicago
# Name: 3, dtype: object
# 974139.2452830189
# 4
# RegionID        93144
# RegionName      79936
# City          El Paso
# Name: 4, dtype: object
# 101875.47169811321
# 5
# RegionID        91733
# RegionName      77084
# City          Houston
# Name: 5, dtype: object
# 121185.28301886792
# 6
# RegionID         61807
# RegionName       10467
# City          New York
# Name: 6, dtype: object
# 292339.24528301886
# 7
# RegionID        84640
# RegionName      60640
# City          Chicago
# Name: 7, dtype: object
# 553078.8679245283
# 8
# RegionID      91940
# ...
